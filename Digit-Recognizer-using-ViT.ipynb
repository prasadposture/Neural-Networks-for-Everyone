# %% [markdown]
# <div style="color:#00ADB5;
#                display:fill;
#                border-radius:5px;
#                background-color:#393E46;
#                font-size: 30px;
#                font-family:sans-serif;
#                letter-spacing:0.5px">
#             <p style="padding: 10px;
#                   color:white;">
#                 <b> Digit Recognizer : ViT</b>
#             </p>
#     </div>

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm, trange

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset, random_split


from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, accuracy_score

import os
import gc
import random

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)
# Out:
# Device: cuda

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(train[['label']])
encoded_cols = list(encoder.get_feature_names_out(['label']))
train[encoded_cols] = encoder.transform(train[['label']])

train.drop(labels=['label'], inplace=True, axis=1)

X_train = train.drop(labels=encoded_cols, axis=1).values
Y_train = train[encoded_cols].values
X_test = test.values

X_train = X_train/255
X_train = np.expand_dims(X_train.reshape(-1,28,28), axis=1)
X_test  = X_test/255
X_test = np.expand_dims(X_test.reshape(-1,28,28), axis=1)

# %%
input_tensor = torch.tensor(X_train, dtype=torch.float32)
output_tensor = torch.tensor(Y_train, dtype=torch.float32)
dataset = TensorDataset(input_tensor, output_tensor)
train_size = round(len(dataset)*0.8)
val_size = len(dataset)-train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
batch_size = 100 # can change later
train_loader = DataLoader(train_dataset,batch_size = batch_size, shuffle=True, num_workers=4 ) # for number of cores at work
val_loader  = DataLoader(val_dataset, batch_size = batch_size)
# Since the iteration over the batches is done for optimizing weights more efficiently

# %% [markdown]
# ## Architecture

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, img_size=28, patch_size=7, in_channels=1, emb_dim=128):
        super(PatchEmbedding, self).__init__()
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        self.proj = nn.Conv2d(in_channels, emb_dim, kernel_size=patch_size, stride=patch_size)
        self.cls_token = nn.Parameter(torch.zeros(1, 1, emb_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, self.num_patches + 1, emb_dim))
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

    def forward(self, x):
        n, c, h, w = x.shape
        x = self.proj(x).flatten(2).transpose(1, 2)
        cls_tokens = self.cls_token.expand(n, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        return x

class TransformerEncoderLayer(nn.Module):
    def __init__(self, emb_dim=128, num_heads=2, ff_dim=256, dropout=0.1):
        super(TransformerEncoderLayer, self).__init__()
        self.self_attn = nn.MultiheadAttention(emb_dim, num_heads, dropout=dropout, batch_first=True)
        self.fc1 = nn.Linear(emb_dim, ff_dim)
        self.fc2 = nn.Linear(ff_dim, emb_dim)
        self.norm1 = nn.LayerNorm(emb_dim)
        self.norm2 = nn.LayerNorm(emb_dim)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x):
        attn_output, _ = self.self_attn(x, x, x)
        x = x + self.dropout1(attn_output)
        x = self.norm1(x)
        ff_output = self.fc2(F.gelu(self.fc1(x)))
        x = x + self.dropout2(ff_output)
        x = self.norm2(x)
        return x

class ViT(nn.Module):
    def __init__(self, img_size=28, patch_size=7, in_channels=1, emb_dim=128, num_heads=2, ff_dim=256, num_layers=4, num_classes=10):
        super(ViT, self).__init__()
        self.patch_embed = PatchEmbedding(img_size, patch_size, in_channels, emb_dim)
        self.encoder_layers = nn.ModuleList([TransformerEncoderLayer(emb_dim, num_heads, ff_dim) for _ in range(num_layers)])
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(emb_dim),
            nn.Linear(emb_dim, num_classes)
        )

    def forward(self, x):
        x = self.patch_embed(x)
        for layer in self.encoder_layers:
            x = layer(x)
        cls_token = x[:, 0]
        out = self.mlp_head(cls_token)
        return out

model = ViT().to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

true_num_epochs = 0
num_epochs = 100
training_loss = []
validation_loss = []
training_acc = []
validation_acc = []

for i in range(num_epochs):
    model.train()
    train_loss = 0.0
    train_acc = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        probabilities = torch.softmax(outputs, dim=1)
        predicted_classes = torch.argmax(probabilities, dim=1)
        true_targets = torch.argmax(targets, dim=1)
        acc = accuracy_score(true_targets.detach().cpu().numpy(), predicted_classes.detach().cpu().numpy())
        train_acc += acc
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
        # break
    train_loss /= len(train_loader.dataset)
    train_acc /= len(train_loader)

    model.eval()
    val_loss = 0.0
    val_acc = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item() * inputs.size(0)

            probabilities = torch.softmax(outputs, dim=1)
            predicted_classes = torch.argmax(probabilities, dim=1)
            true_targets = torch.argmax(targets, dim=1)
            acc = accuracy_score(true_targets.detach().cpu().numpy(), predicted_classes.detach().cpu().numpy())
            val_acc += acc
            # break
    val_loss /= len(val_loader.dataset)
    val_acc /= len(val_loader)
    validation_loss.append(val_loss)
    training_loss.append(train_loss)
    training_acc.append(train_acc)
    validation_acc.append(val_acc)
    true_num_epochs += 1

    print(f"Epoch: {i + 1}/{num_epochs}, Training Loss: {train_loss:.5f}, Validation Loss: {val_loss:.5f}, Training Acc: {train_acc:.5f}, Validation Acc: {val_acc:.5f}")
    # break
torch.save(model.state_dict(), 'ViT.pth')
# Out:
# Epoch: 1/100, Training Loss: 0.69305, Validation Loss: 0.27711, Training Acc: 0.77408, Validation Acc: 0.91774
# Epoch: 2/100, Training Loss: 0.23173, Validation Loss: 0.20624, Training Acc: 0.92908, Validation Acc: 0.93714
# Epoch: 3/100, Training Loss: 0.16997, Validation Loss: 0.18950, Training Acc: 0.94824, Validation Acc: 0.94119
# Epoch: 4/100, Training Loss: 0.13721, Validation Loss: 0.13142, Training Acc: 0.95783, Validation Acc: 0.95964
# Epoch: 5/100, Training Loss: 0.11627, Validation Loss: 0.13205, Training Acc: 0.96437, Validation Acc: 0.96286
# Epoch: 6/100, Training Loss: 0.10495, Validation Loss: 0.11858, Training Acc: 0.96548, Validation Acc: 0.96452
# Epoch: 7/100, Training Loss: 0.09159, Validation Loss: 0.11300, Training Acc: 0.97199, Validation Acc: 0.96607
# Epoch: 8/100, Training Loss: 0.08679, Validation Loss: 0.09841, Training Acc: 0.97164, Validation Acc: 0.96952
# Epoch: 9/100, Training Loss: 0.08203, Validation Loss: 0.10694, Training Acc: 0.97372, Validation Acc: 0.96774
# Epoch: 10/100, Training Loss: 0.07219, Validation Loss: 0.09981, Training Acc: 0.97771, Validation Acc: 0.97274
# Epoch: 11/100, Training Loss: 0.07360, Validation Loss: 0.12283, Training Acc: 0.97637, Validation Acc: 0.96179
# Epoch: 12/100, Training Loss: 0.07078, Validation Loss: 0.09360, Training Acc: 0.97815, Validation Acc: 0.97321
# Epoch: 13/100, Training Loss: 0.06488, Validation Loss: 0.10678, Training Acc: 0.97970, Validation Acc: 0.96810
# Epoch: 14/100, Training Loss: 0.05698, Validation Loss: 0.11029, Training Acc: 0.98146, Validation Acc: 0.97024
# Epoch: 15/100, Training Loss: 0.05944, Validation Loss: 0.12037, Training Acc: 0.98060, Validation Acc: 0.96548
# Epoch: 16/100, Training Loss: 0.06193, Validation Loss: 0.09506, Training Acc: 0.98071, Validation Acc: 0.97119
# Epoch: 17/100, Training Loss: 0.05564, Validation Loss: 0.10061, Training Acc: 0.98250, Validation Acc: 0.97048
# Epoch: 18/100, Training Loss: 0.05645, Validation Loss: 0.09169, Training Acc: 0.98170, Validation Acc: 0.97405
# Epoch: 19/100, Training Loss: 0.05294, Validation Loss: 0.09482, Training Acc: 0.98265, Validation Acc: 0.97452
# Epoch: 20/100, Training Loss: 0.04938, Validation Loss: 0.10512, Training Acc: 0.98369, Validation Acc: 0.97131
# Epoch: 21/100, Training Loss: 0.05106, Validation Loss: 0.09162, Training Acc: 0.98298, Validation Acc: 0.97488
# Epoch: 22/100, Training Loss: 0.04963, Validation Loss: 0.09332, Training Acc: 0.98411, Validation Acc: 0.97393
# Epoch: 23/100, Training Loss: 0.04921, Validation Loss: 0.09345, Training Acc: 0.98366, Validation Acc: 0.97440
# Epoch: 24/100, Training Loss: 0.04801, Validation Loss: 0.09097, Training Acc: 0.98443, Validation Acc: 0.97286
# Epoch: 25/100, Training Loss: 0.04280, Validation Loss: 0.08668, Training Acc: 0.98589, Validation Acc: 0.97607
# Epoch: 26/100, Training Loss: 0.04300, Validation Loss: 0.08824, Training Acc: 0.98607, Validation Acc: 0.97524
# Epoch: 27/100, Training Loss: 0.04386, Validation Loss: 0.10347, Training Acc: 0.98616, Validation Acc: 0.97179
# Epoch: 28/100, Training Loss: 0.03401, Validation Loss: 0.08354, Training Acc: 0.98920, Validation Acc: 0.97750
# Epoch: 29/100, Training Loss: 0.04615, Validation Loss: 0.10143, Training Acc: 0.98479, Validation Acc: 0.97345
# Epoch: 30/100, Training Loss: 0.03888, Validation Loss: 0.08944, Training Acc: 0.98714, Validation Acc: 0.97667
# Epoch: 31/100, Training Loss: 0.04032, Validation Loss: 0.09809, Training Acc: 0.98649, Validation Acc: 0.97464
# Epoch: 32/100, Training Loss: 0.04388, Validation Loss: 0.09439, Training Acc: 0.98568, Validation Acc: 0.97464
# Epoch: 33/100, Training Loss: 0.04016, Validation Loss: 0.09496, Training Acc: 0.98750, Validation Acc: 0.97583
# Epoch: 34/100, Training Loss: 0.03600, Validation Loss: 0.09137, Training Acc: 0.98857, Validation Acc: 0.97512
# Epoch: 35/100, Training Loss: 0.03641, Validation Loss: 0.08637, Training Acc: 0.98815, Validation Acc: 0.97643
# Epoch: 36/100, Training Loss: 0.03672, Validation Loss: 0.09716, Training Acc: 0.98818, Validation Acc: 0.97298
# Epoch: 37/100, Training Loss: 0.03255, Validation Loss: 0.08911, Training Acc: 0.98902, Validation Acc: 0.97714
# Epoch: 38/100, Training Loss: 0.04576, Validation Loss: 0.10323, Training Acc: 0.98509, Validation Acc: 0.97167
# Epoch: 39/100, Training Loss: 0.03752, Validation Loss: 0.07989, Training Acc: 0.98753, Validation Acc: 0.97857
# Epoch: 40/100, Training Loss: 0.03723, Validation Loss: 0.10037, Training Acc: 0.98732, Validation Acc: 0.97345
# Epoch: 41/100, Training Loss: 0.03112, Validation Loss: 0.09367, Training Acc: 0.98973, Validation Acc: 0.97690
# Epoch: 42/100, Training Loss: 0.04587, Validation Loss: 0.07801, Training Acc: 0.98527, Validation Acc: 0.97631
# Epoch: 43/100, Training Loss: 0.02957, Validation Loss: 0.07670, Training Acc: 0.99045, Validation Acc: 0.97988
# Epoch: 44/100, Training Loss: 0.02311, Validation Loss: 0.10016, Training Acc: 0.99217, Validation Acc: 0.97726
# Epoch: 45/100, Training Loss: 0.03258, Validation Loss: 0.08362, Training Acc: 0.98979, Validation Acc: 0.97988
# Epoch: 46/100, Training Loss: 0.02588, Validation Loss: 0.09694, Training Acc: 0.99164, Validation Acc: 0.97452
# Epoch: 47/100, Training Loss: 0.03925, Validation Loss: 0.08804, Training Acc: 0.98720, Validation Acc: 0.97810
# Epoch: 48/100, Training Loss: 0.02751, Validation Loss: 0.09417, Training Acc: 0.99098, Validation Acc: 0.97738
# Epoch: 49/100, Training Loss: 0.03070, Validation Loss: 0.10251, Training Acc: 0.98964, Validation Acc: 0.97286
# Epoch: 50/100, Training Loss: 0.02870, Validation Loss: 0.07847, Training Acc: 0.99074, Validation Acc: 0.98048
# Epoch: 51/100, Training Loss: 0.02479, Validation Loss: 0.10138, Training Acc: 0.99173, Validation Acc: 0.97488
# Epoch: 52/100, Training Loss: 0.03076, Validation Loss: 0.10049, Training Acc: 0.99003, Validation Acc: 0.97345
# Epoch: 53/100, Training Loss: 0.02797, Validation Loss: 0.09359, Training Acc: 0.99113, Validation Acc: 0.97702
# Epoch: 54/100, Training Loss: 0.03104, Validation Loss: 0.08950, Training Acc: 0.99057, Validation Acc: 0.97536
# Epoch: 55/100, Training Loss: 0.03028, Validation Loss: 0.10369, Training Acc: 0.99009, Validation Acc: 0.97226
# Epoch: 56/100, Training Loss: 0.02923, Validation Loss: 0.09733, Training Acc: 0.99015, Validation Acc: 0.97560
# Epoch: 57/100, Training Loss: 0.02636, Validation Loss: 0.09637, Training Acc: 0.99107, Validation Acc: 0.97762
# Epoch: 58/100, Training Loss: 0.02685, Validation Loss: 0.09392, Training Acc: 0.99137, Validation Acc: 0.97810
# Epoch: 59/100, Training Loss: 0.03399, Validation Loss: 0.09963, Training Acc: 0.98866, Validation Acc: 0.97464
# Epoch: 60/100, Training Loss: 0.02673, Validation Loss: 0.10338, Training Acc: 0.99158, Validation Acc: 0.97464
# Epoch: 61/100, Training Loss: 0.02570, Validation Loss: 0.09231, Training Acc: 0.99170, Validation Acc: 0.97857
# Epoch: 62/100, Training Loss: 0.02524, Validation Loss: 0.10867, Training Acc: 0.99179, Validation Acc: 0.97321
# Epoch: 63/100, Training Loss: 0.02992, Validation Loss: 0.08437, Training Acc: 0.99098, Validation Acc: 0.97929
# Epoch: 64/100, Training Loss: 0.02590, Validation Loss: 0.09089, Training Acc: 0.99116, Validation Acc: 0.97940
# Epoch: 65/100, Training Loss: 0.01989, Validation Loss: 0.08954, Training Acc: 0.99336, Validation Acc: 0.98036
# Epoch: 66/100, Training Loss: 0.02645, Validation Loss: 0.09961, Training Acc: 0.99089, Validation Acc: 0.97655
# Epoch: 67/100, Training Loss: 0.02196, Validation Loss: 0.08941, Training Acc: 0.99271, Validation Acc: 0.97917
# Epoch: 68/100, Training Loss: 0.02533, Validation Loss: 0.08912, Training Acc: 0.99170, Validation Acc: 0.97726
# Epoch: 69/100, Training Loss: 0.02976, Validation Loss: 0.08379, Training Acc: 0.99006, Validation Acc: 0.97833
# Epoch: 70/100, Training Loss: 0.02157, Validation Loss: 0.08710, Training Acc: 0.99280, Validation Acc: 0.97881
# Epoch: 71/100, Training Loss: 0.01778, Validation Loss: 0.08461, Training Acc: 0.99432, Validation Acc: 0.98036
# Epoch: 72/100, Training Loss: 0.01774, Validation Loss: 0.08737, Training Acc: 0.99411, Validation Acc: 0.97821
# Epoch: 73/100, Training Loss: 0.02182, Validation Loss: 0.09050, Training Acc: 0.99289, Validation Acc: 0.97810
# Epoch: 74/100, Training Loss: 0.02355, Validation Loss: 0.08160, Training Acc: 0.99265, Validation Acc: 0.97833
# Epoch: 75/100, Training Loss: 0.03018, Validation Loss: 0.09080, Training Acc: 0.99009, Validation Acc: 0.97929
# Epoch: 76/100, Training Loss: 0.02100, Validation Loss: 0.08438, Training Acc: 0.99360, Validation Acc: 0.97917
# Epoch: 77/100, Training Loss: 0.01960, Validation Loss: 0.09161, Training Acc: 0.99405, Validation Acc: 0.97774
# Epoch: 78/100, Training Loss: 0.02440, Validation Loss: 0.09027, Training Acc: 0.99250, Validation Acc: 0.97774
# Epoch: 79/100, Training Loss: 0.02478, Validation Loss: 0.08584, Training Acc: 0.99259, Validation Acc: 0.98024
# Epoch: 80/100, Training Loss: 0.01807, Validation Loss: 0.08797, Training Acc: 0.99408, Validation Acc: 0.97774
# Epoch: 81/100, Training Loss: 0.02629, Validation Loss: 0.10060, Training Acc: 0.99149, Validation Acc: 0.97679
# Epoch: 82/100, Training Loss: 0.01838, Validation Loss: 0.09695, Training Acc: 0.99348, Validation Acc: 0.97655
# Epoch: 83/100, Training Loss: 0.02056, Validation Loss: 0.08800, Training Acc: 0.99351, Validation Acc: 0.97869
# Epoch: 84/100, Training Loss: 0.02280, Validation Loss: 0.07891, Training Acc: 0.99283, Validation Acc: 0.98024
# Epoch: 85/100, Training Loss: 0.01578, Validation Loss: 0.09515, Training Acc: 0.99461, Validation Acc: 0.97940
# Epoch: 86/100, Training Loss: 0.02030, Validation Loss: 0.08966, Training Acc: 0.99345, Validation Acc: 0.97988
# Epoch: 87/100, Training Loss: 0.01975, Validation Loss: 0.09081, Training Acc: 0.99366, Validation Acc: 0.97869
# Epoch: 88/100, Training Loss: 0.01482, Validation Loss: 0.08988, Training Acc: 0.99524, Validation Acc: 0.97905
# Epoch: 89/100, Training Loss: 0.02334, Validation Loss: 0.08307, Training Acc: 0.99265, Validation Acc: 0.97988
# Epoch: 90/100, Training Loss: 0.02549, Validation Loss: 0.13960, Training Acc: 0.99182, Validation Acc: 0.96619
# Epoch: 91/100, Training Loss: 0.02998, Validation Loss: 0.06725, Training Acc: 0.99030, Validation Acc: 0.98226
# Epoch: 92/100, Training Loss: 0.01180, Validation Loss: 0.08657, Training Acc: 0.99610, Validation Acc: 0.98202
# Epoch: 93/100, Training Loss: 0.02123, Validation Loss: 0.09798, Training Acc: 0.99327, Validation Acc: 0.97667
# Epoch: 94/100, Training Loss: 0.01834, Validation Loss: 0.10888, Training Acc: 0.99363, Validation Acc: 0.97655
# Epoch: 95/100, Training Loss: 0.01960, Validation Loss: 0.08649, Training Acc: 0.99372, Validation Acc: 0.97798
# Epoch: 96/100, Training Loss: 0.01640, Validation Loss: 0.09482, Training Acc: 0.99470, Validation Acc: 0.97726
# Epoch: 97/100, Training Loss: 0.02277, Validation Loss: 0.09135, Training Acc: 0.99301, Validation Acc: 0.97726
# Epoch: 98/100, Training Loss: 0.01648, Validation Loss: 0.09074, Training Acc: 0.99473, Validation Acc: 0.97929
# Epoch: 99/100, Training Loss: 0.02392, Validation Loss: 0.11503, Training Acc: 0.99232, Validation Acc: 0.97417
# Epoch: 100/100, Training Loss: 0.01654, Validation Loss: 0.08796, Training Acc: 0.99432, Validation Acc: 0.97952

# %%
epochs = range(1, int(true_num_epochs) + 1)

plt.figure(figsize=(10, 5))

plt.plot(epochs, np.array(training_acc)*100, 'b-o', label='Training Accuracy')
plt.plot(epochs, np.array(validation_acc)*100, 'r-o', label='Validation Accuracy')
plt.title('Training and Validation Accuracy (in percentage)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
epochs = range(1, int(true_num_epochs) + 1)

plt.figure(figsize=(10, 5))

plt.plot(epochs, training_loss, 'b-o', label='Training Loss')
plt.plot(epochs, validation_loss, 'r-o', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# The End
